# %% [markdown]
# ## Scenario 1: A single data scientist participating in an ML competition
#
# This scenario demonstrates how an individual data scientist can use MLflow to track machine learning experiments on their local machine. This is a common setup for solo projects, hackathons, or competitions where collaboration and remote access are not required.
#
# ### MLflow setup overview
# - **Tracking server:** Not used (runs locally, no remote server)
# - **Backend store:** Local filesystem (stores experiment metadata in the `mlruns/` folder)
# - **Artifacts store:** Local filesystem (stores model files and other artifacts in the same `mlruns/` folder)
#
# With this setup, all experiment runs, parameters, metrics, and artifacts are saved locally. You can explore and compare your experiments using the MLflow UI.
#
# ### How to use the MLflow UI
# - You can launch the MLflow UI by running `mlflow ui` in your terminal, or by running the provided code cell in this notebook.
# - The UI will be available at [http://localhost:5000](http://localhost:5000).
# - http://127.0.0.1:5000
# - Use the UI to browse experiments, compare runs, and inspect logged models and artifacts.
#
# > **Tip:** This local setup is ideal for learning and prototyping. For team projects or production, you would typically use a remote tracking server and a more robust backend (e.g., a database and cloud storage).

# %%
# %pip install mlflow
import mlflow
# Out:
# Requirement already satisfied: mlflow in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (3.6.0)
# Requirement already satisfied: mlflow-skinny==3.6.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow) (3.6.0)
# Requirement already satisfied: mlflow-tracing==3.6.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow) (3.6.0)
# Requirement already satisfied: Flask-CORS<7 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow) (6.0.1)
# Requirement already satisfied: Flask<4 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow) (1.17.2)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow) (46.0.3)
# Requirement already satisfied: docker<8,>=4.0.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow) (23.0.0)
# Requirement already satisfied: huey<3,>=2.5.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow) (2.5.4)
# Requirement already satisfied: matplotlib<4 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow) (3.10.7)
# Requirement already satisfied: numpy<3 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow) (2.0.2)
# Requirement already satisfied: pandas<3 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow) (22.0.0)
# Requirement already satisfied: scikit-learn<2 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow) (1.7.2)
# Requirement already satisfied: scipy<2 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow) (1.15.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow) (2.0.44)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (6.2.2)
# Requirement already satisfied: click<9,>=7.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (8.3.1)
# Requirement already satisfied: cloudpickle<4 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (0.73.0)
# Requirement already satisfied: fastapi<1 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (0.117.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (1.38.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (1.38.0)
# Requirement already satisfied: packaging<26 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (6.33.1)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (2.12.4)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (1.2.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow) (0.38.0)
# Requirement already satisfied: Mako in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: tomli in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow) (2.3.0)
# Requirement already satisfied: cffi>=2.0.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from cryptography<47,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (2.43.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny==3.6.0->mlflow) (0.48.0)
# Requirement already satisfied: blinker>=1.9.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from graphene<4->mlflow) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.6.0->mlflow) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from matplotlib<4->mlflow) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from matplotlib<4->mlflow) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from matplotlib<4->mlflow) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from matplotlib<4->mlflow) (3.2.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.6.0->mlflow) (0.59b0)
# Requirement already satisfied: pytz>=2020.1 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow) (0.4.2)
# Requirement already satisfied: six>=1.5 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow) (2025.11.12)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (0.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from starlette<0.49.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow) (4.11.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.49.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow) (1.3.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.49.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow) (1.3.1)
# Requirement already satisfied: h11>=0.8 in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from uvicorn<1->mlflow-skinny==3.6.0->mlflow) (0.16.0)
# Requirement already satisfied: pycparser in /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow) (2.23)
# Note: you may need to restart the kernel to use updated packages.

# %%
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'file:///Users/marianasaca/Documents/Documents%20-%20Mariana%E2%80%99s%20MacBook%20Air/MDB%20Term%202/ML%20Ops/ie-mlops-nyc-taxis/03-experiment-tracking/mlruns'

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='file:///Users/marianasaca/Documents/Documents%20-%20Mariana%E2%80%99s%20MacBook%20Air/MDB%20Term%202/ML%20Ops/ie-mlops-nyc-taxis/03-experiment-tracking/mlruns/583326327153127534', creation_time=1764073747842, experiment_id='583326327153127534', last_update_time=1764073747842, lifecycle_stage='active', name='my-experiment-1', tags={}>,
#  <Experiment: artifact_location='file:///Users/marianasaca/Documents/Documents%20-%20Mariana%E2%80%99s%20MacBook%20Air/MDB%20Term%202/ML%20Ops/ie-mlops-nyc-taxis/03-experiment-tracking/mlruns/0', creation_time=1764073733512, experiment_id='0', last_update_time=1764073733512, lifecycle_stage='active', name='Default', tags={}>]

# %% [markdown]
# ### Creating an experiment and logging a new run

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score, confusion_matrix
import numpy as np
import mlflow
import sklearn
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

mlflow.set_experiment("my-experiment-1")

X, y = load_iris(return_X_y=True)
class_names = load_iris().target_names

models = [
    ("LogisticRegression", LogisticRegression(C=1.0, random_state=42, max_iter=1000, solver="lbfgs")),
    ("RandomForestClassifier", RandomForestClassifier(n_estimators=100, random_state=42))
]

for model_name, model in models:
    with mlflow.start_run() as run:
        mlflow.set_tag("model_type", model_name)
        mlflow.log_param("sklearn_version", sklearn.__version__)
        model.fit(X, y)
        y_pred = model.predict(X)
        acc = accuracy_score(y, y_pred)
        mlflow.log_metric("accuracy", acc)
        # Log confusion matrix as labeled DataFrame
        cm = confusion_matrix(y, y_pred)
        cm_df = pd.DataFrame(cm, index=class_names, columns=class_names)
        cm_df.to_csv("confusion_matrix_labeled.csv")
        mlflow.log_artifact("confusion_matrix_labeled.csv")
        # Confusion matrix heatmap as image
        plt.figure(figsize=(5,4))
        sns.heatmap(cm_df, annot=True, fmt="d", cmap="Blues")
        plt.title(f"Confusion Matrix ({model_name})")
        plt.ylabel("True label")
        plt.xlabel("Predicted label")
        plt.tight_layout()
        plt.savefig("confusion_matrix_heatmap.png")
        plt.close()
        mlflow.log_artifact("confusion_matrix_heatmap.png")
        # Provide input_example and use 'name' instead of deprecated 'artifact_path'
        input_example = np.expand_dims(X[0], axis=0)
        mlflow.sklearn.log_model(model, name="models", input_example=input_example)
        mlflow.set_tag("n_classes", len(np.unique(y)))
        mlflow.set_tag("run_time", datetime.datetime.now().isoformat())
        mlflow.set_tag("description", f"{model_name} on Iris dataset")
        print(f"Logged run for {model_name}, accuracy={acc:.3f}")
# Out:
# Logged run for LogisticRegression, accuracy=0.973
# Logged run for RandomForestClassifier, accuracy=1.000

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='file:///Users/marianasaca/Documents/Documents%20-%20Mariana%E2%80%99s%20MacBook%20Air/MDB%20Term%202/ML%20Ops/ie-mlops-nyc-taxis/03-experiment-tracking/mlruns/583326327153127534', creation_time=1764073747842, experiment_id='583326327153127534', last_update_time=1764073747842, lifecycle_stage='active', name='my-experiment-1', tags={}>,
#  <Experiment: artifact_location='file:///Users/marianasaca/Documents/Documents%20-%20Mariana%E2%80%99s%20MacBook%20Air/MDB%20Term%202/ML%20Ops/ie-mlops-nyc-taxis/03-experiment-tracking/mlruns/0', creation_time=1764073733512, experiment_id='0', last_update_time=1764073733512, lifecycle_stage='active', name='Default', tags={}>]

# %%
# Launch MLflow UI (default: uses local mlruns/ folder)
import subprocess
import sys

# This will run 'mlflow ui' as a background process
subprocess.Popen([sys.executable, '-m', 'mlflow', 'ui'])
print("MLflow UI started. Open http://localhost:5000 in your browser.")
# Out:
# MLflow UI started. Open http://localhost:5000 in your browser.

# %% [markdown]
# ### Interacting with the model registry

# %%
from mlflow.tracking import MlflowClient


client = MlflowClient()

# %%
from mlflow.exceptions import MlflowException

try:
    client.search_registered_models()
except MlflowException:
    print("It's not possible to access the model registry :(")
# Out:
# /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages/mlflow/server/handlers.py:256: FutureWarning: Filesystem tracking backend (e.g., './mlruns') is deprecated. Please switch to a database backend (e.g., 'sqlite:///mlflow.db'). For feedback, see: https://github.com/mlflow/mlflow/issues/18534
#   return FileStore(store_uri, artifact_uri)
# /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages/mlflow/server/handlers.py:285: FutureWarning: Filesystem model registry backend (e.g., './mlruns') is deprecated. Please switch to a database backend (e.g., 'sqlite:///mlflow.db'). For feedback, see: https://github.com/mlflow/mlflow/issues/18534
#   return FileStore(store_uri)
# [MLflow] Security middleware enabled with default settings (localhost-only). To allow connections from other hosts, use --host 0.0.0.0 and configure --allowed-hosts and --cors-allowed-origins.
# ERROR:    [Errno 48] Address already in use
# INFO:     127.0.0.1:55500 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55500 - "GET /static-files/static/js/main.380f9aea.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55501 - "GET /static-files/static/css/main.280d6c90.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55500 - "GET /static-files/static/js/3617.10568100.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55501 - "GET /static-files/static/js/5759.45405231.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55502 - "GET /static-files/static/js/762.335831d3.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55502 - "GET /ajax-api/2.0/mlflow/experiments/search?max_results=5&order_by=last_update_time+DESC HTTP/1.1" 200 OK
# /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages/mlflow/server/handlers.py:256: FutureWarning: Filesystem tracking backend (e.g., './mlruns') is deprecated. Please switch to a database backend (e.g., 'sqlite:///mlflow.db'). For feedback, see: https://github.com/mlflow/mlflow/issues/18534
#   return FileStore(store_uri, artifact_uri)
# /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages/mlflow/server/handlers.py:256: FutureWarning: Filesystem tracking backend (e.g., './mlruns') is deprecated. Please switch to a database backend (e.g., 'sqlite:///mlflow.db'). For feedback, see: https://github.com/mlflow/mlflow/issues/18534
#   return FileStore(store_uri, artifact_uri)
# INFO:     127.0.0.1:55506 - "GET /ajax-api/2.0/mlflow/experiments/search?max_results=5&order_by=last_update_time+DESC HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55512 - "GET /static-files/static/js/565.222c289f.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55510 - "GET /static-files/static/css/565.fd7db8ca.chunk.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55511 - "GET /static-files/static/js/6016.a73a7053.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55508 - "GET /static-files/static/js/8799.de860ae0.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55509 - "GET /static-files/static/js/2365.08729b99.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55508 - "POST /graphql HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55508 - "GET /ajax-api/2.0/mlflow/traces?experiment_ids=583326327153127534&order_by=timestamp_ms%20DESC&max_results=1&filter= HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55512 - "GET /static-files/static/js/4499.a03329c0.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55508 - "GET /static-files/static/js/8975.6d6dd5b6.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55511 - "GET /static-files/static/js/8813.6db77245.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55510 - "GET /static-files/static/js/683.b5476dee.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55513 - "GET /static-files/static/js/1090.9c665bdd.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55511 - "GET /static-files/static/css/9563.3a1ae3b9.chunk.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55510 - "GET /static-files/static/js/8169.4fbe9ffa.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55511 - "GET /static-files/static/js/194.bffb2d90.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55513 - "GET /static-files/static/js/2334.fa3bbeb7.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55510 - "GET /static-files/static/js/8800.a03d202d.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55511 - "GET /static-files/static/js/8906.83fbad33.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55513 - "GET /static-files/static/js/3887.80196d3a.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55510 - "GET /static-files/static/js/2354.b6575389.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55511 - "GET /static-files/static/js/1538.e01eb384.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55510 - "GET /static-files/static/js/9635.23ed64fc.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55510 - "GET /static-files/static/js/657.85c37963.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55510 - "GET /static-files/static/js/8555.3803d908.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55513 - "GET /static-files/static/js/9791.9560c16c.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55511 - "GET /static-files/static/js/5167.7a115efb.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55511 - "GET /static-files/static/js/363.a9a32c36.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55513 - "GET /static-files/static/js/4802.4b3988ed.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55510 - "GET /static-files/static/js/1241.879a3257.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55511 - "GET /static-files/static/js/1573.82c5c603.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55513 - "GET /static-files/static/js/9563.941d9737.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55512 - "GET /static-files/static/css/1575.05d081e5.chunk.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55511 - "GET /static-files/static/js/1575.6f955232.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55513 - "GET /static-files/static/js/5964.4d84f1bd.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55512 - "GET /ajax-api/2.0/mlflow/gateway-proxy?gateway_path=api%2F2.0%2Fendpoints%2F HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55508 - "POST /ajax-api/2.0/mlflow/experiments/search-datasets HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55513 - "POST /ajax-api/2.0/mlflow/logged-models/search HTTP/1.1" 200 OK
# /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages/mlflow/server/handlers.py:256: FutureWarning: Filesystem tracking backend (e.g., './mlruns') is deprecated. Please switch to a database backend (e.g., 'sqlite:///mlflow.db'). For feedback, see: https://github.com/mlflow/mlflow/issues/18534
#   return FileStore(store_uri, artifact_uri)
# INFO:     127.0.0.1:55509 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55510 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55510 - "GET /ajax-api/2.0/mlflow/gateway-proxy?gateway_path=api%2F2.0%2Fendpoints%2F HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55509 - "POST /ajax-api/2.0/mlflow/logged-models/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55511 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55517 - "GET /ajax-api/2.0/mlflow/traces?experiment_ids=583326327153127534&order_by=timestamp_ms%20DESC&max_results=1&filter= HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55518 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55523 - "POST /ajax-api/2.0/mlflow/experiments/set-experiment-tag HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55523 - "POST /graphql HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55524 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55527 - "GET /static-files/static/js/1876.132109ab.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55529 - "GET /static-files/static/js/1352.43b05edb.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55526 - "GET /static-files/static/js/6831.d1a4e11f.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55525 - "GET /static-files/static/js/8977.f9196701.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55527 - "GET /static-files/static/js/4484.9cee0180.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55528 - "GET /static-files/static/js/5776.36e18643.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55530 - "GET /static-files/static/css/8923.b80374b9.chunk.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55527 - "GET /static-files/static/js/8923.a9ff1c8d.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55527 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=run_id%3D%27c40ad6ade9c148de953ee6a8b49e5baf%27 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55525 - "POST /graphql HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55527 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%25c40ad6ade9c148de953ee6a8b49e5baf%25%22 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55528 - "POST /ajax-api/2.0/mlflow/logged-models/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55525 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages/mlflow/server/handlers.py:285: FutureWarning: Filesystem model registry backend (e.g., './mlruns') is deprecated. Please switch to a database backend (e.g., 'sqlite:///mlflow.db'). For feedback, see: https://github.com/mlflow/mlflow/issues/18534
#   return FileStore(store_uri)
# /Users/marianasaca/Documents/Documents - Mariana’s MacBook Air/MDB Term 2/ML Ops/ie-mlops-nyc-taxis/.venv/lib/python3.10/site-packages/mlflow/server/handlers.py:285: FutureWarning: Filesystem model registry backend (e.g., './mlruns') is deprecated. Please switch to a database backend (e.g., 'sqlite:///mlflow.db'). For feedback, see: https://github.com/mlflow/mlflow/issues/18534
#   return FileStore(store_uri)
# INFO:     127.0.0.1:55525 - "POST /ajax-api/2.0/mlflow/experiments/search-datasets HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55525 - "GET /ajax-api/2.0/mlflow/gateway-proxy?gateway_path=api%2F2.0%2Fendpoints%2F HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55528 - "POST /ajax-api/2.0/mlflow/logged-models/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55527 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55534 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55540 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55547 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55556 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55561 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55564 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55568 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55570 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55575 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55578 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55583 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55587 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55592 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
